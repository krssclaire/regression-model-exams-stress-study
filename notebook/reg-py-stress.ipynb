# %% [markdown]
# # Grafici
# 1. Piano 3D
#     _Variabili_:
#     - Esami al semestre (X)
#     - Livello di stress percepito (y)
#     - Genere (D)
# 2. Grafico a dispersione
#     _Variabili_:
#     - Esami al semestre (X)
#     - Genere (D)
# 3. Grafico a dispersione
#     _Variabili_:
#     - Esami al semestre (X)
#     - Livello di stress percepito (y)
# 4.Piano delle rette di regressione
#     _Variabili_:
#     - Esami al semestre (X)
#     - Livello di stress percepito (y)

# %% [markdown]
# ## 1. Piano 3D

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.linear_model import LinearRegression

# load data
survey_data_path = '../dataset/dati-sondaggio-stress.csv'
survey_data = pd.read_csv(survey_data_path)

# define parameters X, y
y = survey_data.LivelloStress
X = survey_data[['EsamiSem', 'Genere']]

# define model
model = LinearRegression()

# fit model
model.fit(X, y)

# grid (piano della regressione)
gender_range = np.linspace(X['Genere'].min(), X['Genere'].max(), 10)
esami_sem_range = np.linspace(X['EsamiSem'].min(), X['EsamiSem'].max(), 10)
f_grid, q_grid = np.meshgrid(gender_range, esami_sem_range)
x_grid = np.c_[f_grid.ravel(), q_grid.ravel()]
y_pred_grid = model.predict(x_grid).reshape(f_grid.shape)

# setup 3d graph
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

# real points
ax.scatter(X['Genere'], X['EsamiSem'], y, color='orange', label='Osservazioni')

# regression plan
ax.plot_surface(f_grid, q_grid, y_pred_grid, color='sandybrown', alpha=0.5)

# graph plot
ax.set_xlabel('Genere (D)')
ax.set_ylabel('Esami al semestre (X)')
ax.set_zlabel('Livello di stress (Y)')
plt.legend()
plt.show()
# Out:
# C:\Users\krist\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## 2. Grafico a dispersione

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.linear_model import LinearRegression

# load data
survey_data_path = '../dataset/dati-sondaggio-stress.csv'
survey_data = pd.read_csv(survey_data_path)

# define parameters X, y
y = survey_data.LivelloStress
X = survey_data[['EsamiSem', 'Genere']]

# define model
model = LinearRegression()

# fit model
model.fit(X, y)
y_pred = model.predict(X)

# graph plot
plt.figure(figsize=(8, 5))
plt.scatter(X['Genere'], y, color='orange', label='Osservazioni')
#plt.plot(X['Genere'], y_pred, color='green', label='Retta di regressione')
plt.xlabel('Genere')
plt.ylabel('Esami al semestre')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 3. Grafico a dispersione

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.linear_model import LinearRegression

# load data
survey_data_path = '../dataset/dati-sondaggio-stress.csv'
survey_data = pd.read_csv(survey_data_path)

# define parameters X, y
y = survey_data.LivelloStress
X = survey_data[['EsamiSem', 'Genere']]

# define model
model = LinearRegression()

# fit model
model.fit(X, y)
y_pred = model.predict(X)

# graph plot
plt.scatter(X['EsamiSem'], y, color='orange', label='Osservazioni')
#plt.plot(X['Genere'], y_pred, color='green', label='Retta di regressione')
plt.xlabel('Esami al semestre')
plt.ylabel('Livelli di stress')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 4.Piano delle rette di regressione

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt

# line coeff --> data from excel model results
intercetta = 10.1400463
pendenza = -1.211805556
intercetta_2 = intercetta + 2.349537037

# arbitrary values
x = np.linspace(0, 10, 100) 

# calculate y = β₀ + β₁x
y_1 = intercetta + pendenza * x
y_2 = intercetta_2 + pendenza * x

# graph plot
plt.figure(figsize=(8, 5))
plt.plot(x, y_2, color='sandybrown', label='y | D = 1 (Femmine)')
plt.plot(x, y_1, color='orange', label='y | D = 0 (Maschi)')
plt.xlabel("Esami al semestre")
plt.ylabel("Livelli di stress")
plt.legend()
plt.grid(True)
plt.show()
